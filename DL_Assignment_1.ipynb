# %%
#DL_Assignment_1

# %% [markdown]
# #1.	What is the function of a summation junction of a neuron? What is threshold activation function?

# %%
Sol: In the summation, all features are multiplied by their weights and bias are summed up. (Y=W1X1+W2X2+b). 
    This summed function is applied over an Activation function.
    
    These certain conditions which differ neuron to neuron are called Threshold.
    The threshold governs the choice to turn a projected probability or scores into a class label. 
    For normalized projected probabilities in the range of 0 to 1, the threshold is set to 0.5 by default.

# %% [markdown]
# #2.	What is a step function? What is the difference of step function with threshold function?

# %%
Sol: Step Function is one of the simplest kind of activation functions. 
    In this, we consider a threshold value and if the value of net input say 
    y is greater than the threshold then the neuron is activated. 
    
    A step function is a function like that used by the original Perceptron. 
    The output is a certain value, A1, if the input sum is above a certain threshold 
    and A0 if the input sum is below a certain threshold. 
    The values used by the Perceptron were A1 = 1 and A0 = 0.

# %% [markdown]
# #3.	Explain the McCulloch–Pitts model of neuron.

# %% [markdown]
# Sol:The McCulloch-Pitts neural model, which was the earliest ANN model,
#     has only two types of inputs — Excitatory and Inhibitory.
#     The excitatory inputs have weights of positive magnitude and the
#     inhibitory weights have weights of negative magnitude.
#     The inputs of the McCulloch-Pitts neuron could be either 0 or 1.![McCulloch%E2%80%93Pitts%20model%20of%20neuron.jfif](attachment:McCulloch%E2%80%93Pitts%20model%20of%20neuron.jfif)

# %% [markdown]
# #4.Explain the ADALINE network model.

# %% [markdown]
# Sol:An Adeline model consists of trainable weights.
#     The inputs are of two values (+1 or -1) and the weights have signs (positive or negative).
#     Initially random weights are assigned. The net input calculated is applied to a quantizer
#     transfer function (possibly activation function) that restores the output to +1 or -1.![ADALINE%20network%20model.jfif](attachment:ADALINE%20network%20model.jfif)

# %% [markdown]
# #5.	What is the constraint of a simple perceptron? Why it may fail with a real-world data set?

# %%
Sol: one of the challenges with the single-layer perceptrons is that the constraints
    limit the algorithm's ability to accurately classify data. Specifically,
    the primary constraint is that the data must be linearly separable
    Why is a single perceptron incapable of solving the exclusive or problem?
    A "single-layer" perceptron can't implement XOR. The reason is because the 
    classes in XOR are not linearly separable. You cannot draw a straight line to 
    separate the points (0,0),(1,1) from the points (0,1),(1,0). Led to invention of multi-layer networks.

# %% [markdown]
# #6.What is linearly inseparable problem? What is the role of the hidden layer?

# %%
Sol:Clearly not all decision problems are linearly separable: they cannot be solved using a linear 
        decision boundary. Problems like these are termed linearly inseparable.
        The hidden layers' job is to transform the inputs into something that the output layer can use.

# %% [markdown]
# #7.	Explain XOR problem in case of a simple perceptron.

# %%
Sol:The XOr problem is that we need to build a Neural Network (a perceptron in our case) 
    to produce the truth table related to the XOr logical operator. 
    This is a binary classification problem. Hence, supervised learning is a better way to solve it.

# %% [markdown]
# #8.	Design a multi-layer perceptron to implement A XOR B.

# %% [markdown]
# Sol:
#     Hence, we have built a multi layered perceptron with the following weights and it predicts the output of a XOr logical operator.
# ...
# Using the formulae for AND, NOT and OR gates, we get:
# h1 = σ((1-x1) + x2) = σ((-1)x1 + x2 + 1)
# h2 = σ(x1 + (1-x2)) = σ(x1 + (-1)x2 + 1)
# y = σ(h1 + h2) = σ(h1 + h2 + 0)![multi-layer%20perceptron%20to%20implement%20A%20XOR%20B.jfif](attachment:multi-layer%20perceptron%20to%20implement%20A%20XOR%20B.jfif)

# %% [markdown]
# #9.	Explain the single-layer feed forward architecture of ANN.

# %% [markdown]
# Sol:
#     A Feed Forward Neural Network is commonly seen in its simplest form as a single layer perceptron.
#     In this model, a series of inputs enter the layer and are multiplied by the weights.
#     Each value is then added together to get a sum of the weighted input values.
#     ![single-layer%20feed%20forward%20architecture%20of%20ANN.png](attachment:single-layer%20feed%20forward%20architecture%20of%20ANN.png)

# %% [markdown]
# #10.Explain the competitive network architecture of ANN.

# %% [markdown]
# Sol:
#     A Competitive learning is an artificial neural network learning process where
#     different neurons or processing elements compete on who is allowed to learn to represent the current input.
#
#     Competitive learning is a form of unsupervised learning in artificial neural networks,
#     in which nodes compete for the right to respond to a subset of the input data. A variant
#     of Hebbian learning, competitive learning works by increasing the specialization of each node in the network.
#     ![competitive%20network%20architecture%20of%20ANN.png](attachment:competitive%20network%20architecture%20of%20ANN.png)

# %% [markdown]
# #11.Consider a multi-layer feed forward neural network. Enumerate and explain steps in the backpropagation algorithm used to train the network.

# %% [markdown]
# Sol:
#     Below are the steps involved in Backpropagation:
#         Step – 1: Forward Propagation.
#             Step – 2: Backward Propagation.
#                 Step – 3: Putting all the values together and calculating the updated weight value.
#     The algorithm is used to effectively train a neural network through a method called chain rule.
#     In simple terms, after each forward pass through a network, backpropagation performs a backward
#     pass while adjusting the model's parameters (weights and biases).
# ![backward%20propagation.jpg](attachment:backward%20propagation.jpg)

# %% [markdown]
# #12.What are the advantages and disadvantages of neural networks?

# %%
Sol:
    What are the Advantages of Neural Networks?
    1.Efficiency
    2.Continuous Learning
    3.Data retrieval
    4.Multitasking is one of the common advantages of Neural Networks
    5.Wide Applications
    What are the Disadvantages of Neural Networks?
    1. Hardware dependent
    2. Complex Algorithms are foreseen disadvantages of Neural Networks
    3. Black Box Nature
    4. Approximate Results
    5. Data-dependency

# %% [markdown]
# #13.Write short notes on any two of the following:
# 1.	Biological neuron
# 2.	ReLU function
# 3.	Single-layer feed forward ANN
# 4.	Gradient descent
# 5.	Recurrent networks

# %%
Sol:
   1. Biological neurons, consisting of a cell body, axons, dendrites and synapses, 
    are able to process and transmit neural activation.
     In this neural network, the processing is carried out by neurons.
   2.ReLU function
    As a consequence, the usage of ReLU helps to prevent the exponential growth in the 
    computation required to operate the neural network. If the CNN scales in size, 
    the computational cost of adding extra ReLUs increases linearly.
  3.Single-layer feed forward ANN
    For a single-layer feedforward network, there is an input layer and an output layer.
    The input layer is not counted since no computation takes place in this layer. 
    There is a unidirectional connection between the input nodes, in a single-layer network, 
    and the output layer of neurons.
  4.Gradient descent
    Gradient descent is an optimization algorithm which is commonly-used to train machine learning models
    and neural networks. Training data helps these models learn over time, and the cost function within 
    gradient descent specifically acts as a barometer, gauging its accuracy with each iteration of parameter updates.
  5.Recurrent networks
    A Recurrent Neural Network is a type of neural network that contains loops, allowing
    information to be stored within the network. In short, Recurrent Neural Networks use 
    their reasoning from previous experiences to inform the upcoming events. Recurrent models
    are valuable in their ability to sequence vectors, which opens up the API to performing more 
    complicated tasks.
